# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pyana

# %%
spec = np.loadtxt('/home/milic/codes/snapi/test_inv/falc_61_5250.dat',unpack=True)

# %%
spec.shape
# Out:
# (5, 51)

# %%
plt.plot(spec[0]*1E8,spec[1])

# %%
spec[1:].shape
# Out:
# (4, 51)

# %%
spec_to_inv = spec[1:].reshape(1,1,4,51)

# %%
pyana.fzwrite('/home/milic/codes/snapi/test_inv/mock_spectrum.f0',spec_to_inv)
